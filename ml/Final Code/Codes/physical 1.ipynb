# %%
import pandas as pd

# %%
# read the Dataset met.csv(archive (2))
df0 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\archive (2)\\met.csv")

# %%
df0.head()
# Out:
#    Unnamed: 0   Actvitiy  Code   MET  \
# 0           0  Bicycling  1004  16.0
# 1           1  Bicycling  1008   8.5
# 2           2  Bicycling  1009   8.5
# 3           3  Bicycling  1010   4.0
# 4           4  Bicycling  1011   6.8
#
#                                          Description
# 0            Bicycling, mountain, competitive racing
# 1                                     Bicycling, BMX
# 2                       Bicycling, mountain, general
# 3  Bicycling, <10 mph, leisure, to work or for pl...
# 4        Bicycling, to/from work, self selected pace

# %%
df0.columns
# Out:
# Index(['Unnamed: 0', 'Actvitiy', 'Code', 'MET', 'Description'], dtype='object')

# %%
df0.shape
# Out:
# (1125, 5)

# %%
df = df0.drop(columns=['Unnamed: 0', 'Code', 'MET',])

# %%
df.head()
# Out:
#     Actvitiy                                        Description
# 0  Bicycling            Bicycling, mountain, competitive racing
# 1  Bicycling                                     Bicycling, BMX
# 2  Bicycling                       Bicycling, mountain, general
# 3  Bicycling  Bicycling, <10 mph, leisure, to work or for pl...
# 4  Bicycling        Bicycling, to/from work, self selected pace

# %%
df.columns
# Out:
# Index(['Actvitiy', 'Description'], dtype='object')

# %%
df.to_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\Final Code\\Physical Information\\Physical Activities\\physical_activity.csv")
