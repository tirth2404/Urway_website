# %%
import pandas as pd

# %%
# read the Dataset impact_of_extracurricular_activites_on_academic_performance_of_students.csv
df0 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\impact_of_extracurricular_activites_on_academic_performance_of_students.csv")

# %%
df0.head()
# Out:
#   Student_ID    Extracurricular_Activity   GPA  Wellbeing_Score
# 0      S0001  Volunteer Work (Low Hours)  2.78              5.8
# 1      S0002     Sports (High Intensity)  3.43              6.2
# 2      S0003     Sports (High Intensity)  2.44              5.0
# 3      S0004  Volunteer Work (Low Hours)  3.13              6.3
# 4      S0005    Clubs (High Involvement)  2.88              6.3

# %%
df0.columns
# Out:
# Index(['Student_ID', 'Extracurricular_Activity', 'GPA', 'Wellbeing_Score'], dtype='object')

# %%
df  = df0.drop(columns=['Student_ID', 'GPA', 'Wellbeing_Score'])

# %%
df.head()
# Out:
#      Extracurricular_Activity
# 0  Volunteer Work (Low Hours)
# 1     Sports (High Intensity)
# 2     Sports (High Intensity)
# 3  Volunteer Work (Low Hours)
# 4    Clubs (High Involvement)

# %%
df.columns
# Out:
# Index(['Extracurricular_Activity'], dtype='object')
