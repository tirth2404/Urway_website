# %%
import pandas as pd

# %%
# read the Dataset random_fitness_dataset.csv(archive (4))
df0 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\archive (4)\\random_fitness_dataset.csv")

# %%
df0.head()
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
#
#    weight_kg
# 0       84.3
# 1       79.6
# 2       88.3
# 3       69.0
# 4       61.6

# %%
df0.columns
# Out:
# Index(['record_id', 'timestamp', 'user_id', 'age', 'gender', 'activity_type',
#        'duration_min', 'calories_burned', 'heart_rate_avg', 'steps',
#        'sleep_hours', 'weight_kg'],
#       dtype='object')

# %%
df = df0.drop(columns=['record_id', 'timestamp', 'user_id', 'age', 'gender',
    'calories_burned', 'heart_rate_avg', 'steps'])

# %%
df.head()
# Out:
#        activity_type  duration_min  sleep_hours  weight_kg
# 0            Cycling             7          7.0       84.3
# 1  Strength Training            83          5.7       79.6
# 2            Cycling           118          6.6       88.3
# 3           Swimming            75          7.9       69.0
# 4               Yoga            76          5.0       61.6

# %%
df.columns
# Out:
# Index(['activity_type', 'duration_min', 'sleep_hours', 'weight_kg'], dtype='object')

# %%
df.shape
# Out:
# (200, 4)

# %%
df.to_csv()
