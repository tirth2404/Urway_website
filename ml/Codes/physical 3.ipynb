# %%
import pandas as pd

# %%
# read the Dataset mental_wellness_train.csv(archive (3))
df01 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\archive (3)\\mental_wellness_train.csv")
# read the Dataset mental_wellness_tracker.csv(archive (3))
df02 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\archive (3)\\mental_wellness_tracker.csv")
# read the Dataset mental_wellness_test.csv(archive (3))
df03 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\archive (3)\\mental_wellness_test.csv")

# %%
print(df01.shape)
print(df02.shape)
print(df03.shape)
# Out:
# (1200, 12)
# (1500, 12)
# (300, 12)

# %%
df01.head()
# Out:
#   User_ID        Date  Mood_Score  Sleep_Hours Sleep_Quality  \
# 0    U038  2023-06-07           7         10.0     Excellent
# 1    U046  2023-06-19           2          5.7          Good
# 2    U015  2023-06-03           3          7.5          Good
# 3    U014  2023-06-24           4          5.6          Good
# 4    U016  2023-06-02          10          7.3     Excellent
#
#    Screen_Time_Hours  Physical_Activity_Min  Social_Interaction_Hours  \
# 0                5.1                     41                       1.8
# 1                5.5                     36                       0.9
# 2                1.0                      7                       6.6
# 3                3.7                     35                       1.3
# 4                5.4                     29                       3.6
#
#    Work_Productivity_Score Weather Diet_Quality  Stress_Level
# 0                       10   Sunny         Good             3
# ...

# %%
df02.head()
# Out:
#   User_ID        Date  Mood_Score  Sleep_Hours Sleep_Quality  \
# 0    U001  2023-06-01           5          8.5          Fair
# 1    U001  2023-06-02           6          8.0          Good
# 2    U001  2023-06-03           7          7.4          Good
# 3    U001  2023-06-04           3          7.9          Fair
# 4    U001  2023-06-05           4          6.9          Good
#
#    Screen_Time_Hours  Physical_Activity_Min  Social_Interaction_Hours  \
# 0               10.0                     14                       1.1
# 1                4.8                      0                       3.4
# 2                3.5                     38                       2.3
# 3                4.5                     46                       0.9
# 4                2.5                      7                       0.0
#
#    Work_Productivity_Score Weather Diet_Quality  Stress_Level
# 0                        6   Rainy         Poor             5
# ...

# %%
df03.head()
# Out:
#   User_ID        Date  Mood_Score  Sleep_Hours Sleep_Quality  \
# 0    U001  2023-06-02           6          8.0          Good
# 1    U001  2023-06-09           4         10.0     Excellent
# 2    U001  2023-06-14           8          6.5          Fair
# 3    U001  2023-06-15          10          8.0          Fair
# 4    U001  2023-06-21           6          7.2          Poor
#
#    Screen_Time_Hours  Physical_Activity_Min  Social_Interaction_Hours  \
# 0                4.8                      0                       3.4
# 1                4.0                     39                       3.4
# 2                4.4                     34                       1.4
# 3                4.0                     62                       0.0
# 4                4.5                     14                       1.7
#
#    Work_Productivity_Score Weather Diet_Quality  Stress_Level
# 0                        6  Cloudy      Average             4
# ...

# %%
df0 = pd.concat([df01, df02, df03], axis=0)

# %%
df0.shape
# Out:
# (3000, 12)

# %%
df0 = df0.drop_duplicates()

# %%
df0.shape
# Out:
# (1500, 12)

# %%
df0.head()
# Out:
#   User_ID        Date  Mood_Score  Sleep_Hours Sleep_Quality  \
# 0    U038  2023-06-07           7         10.0     Excellent
# 1    U046  2023-06-19           2          5.7          Good
# 2    U015  2023-06-03           3          7.5          Good
# 3    U014  2023-06-24           4          5.6          Good
# 4    U016  2023-06-02          10          7.3     Excellent
#
#    Screen_Time_Hours  Physical_Activity_Min  Social_Interaction_Hours  \
# 0                5.1                     41                       1.8
# 1                5.5                     36                       0.9
# 2                1.0                      7                       6.6
# 3                3.7                     35                       1.3
# 4                5.4                     29                       3.6
#
#    Work_Productivity_Score Weather Diet_Quality  Stress_Level
# 0                       10   Sunny         Good             3
# ...

# %%
df0.columns
# Out:
# Index(['User_ID', 'Date', 'Mood_Score', 'Sleep_Hours', 'Sleep_Quality',
#        'Screen_Time_Hours', 'Physical_Activity_Min',
#        'Social_Interaction_Hours', 'Work_Productivity_Score', 'Weather',
#        'Diet_Quality', 'Stress_Level'],
#       dtype='object')

# %%
df = df0.drop(columns=['User_ID', 'Date', 'Mood_Score', 'Screen_Time_Hours',
    'Social_Interaction_Hours', 'Work_Productivity_Score', 'Weather',])

# %%
df.head()
# Out:
#    Sleep_Hours Sleep_Quality  Physical_Activity_Min Diet_Quality  Stress_Level
# 0         10.0     Excellent                     41         Good             3
# 1          5.7          Good                     36         Good             8
# 2          7.5          Good                      7         Good             8
# 3          5.6          Good                     35      Average             5
# 4          7.3     Excellent                     29      Average             1

# %%
df.columns
# Out:
# Index(['Sleep_Hours', 'Sleep_Quality', 'Physical_Activity_Min', 'Diet_Quality',
#        'Stress_Level'],
#       dtype='object')

# %%
df.to_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\Final Code\\Physical Information\\Mental Wellness\\mental_wellness.csv")
