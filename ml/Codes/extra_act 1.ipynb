# %%
import pandas as pd

# %%
# read the Dataset student_data_extended.csv
df0 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\student_data_extended.csv")

# %%
df0.head()
# Out:
#    StudentID       Name  AcademicInterest ExtracurricularActivities  \
# 0          1  Student 1        Psychology               Debate Club
# 1          2  Student 2        Psychology               Debate Club
# 2          3  Student 3           History           Volunteer Group
# 3          4  Student 4  Computer Science           Volunteer Group
# 4          5  Student 5  Computer Science               Sports Team
#
#                                               Skills  Location YearOfStudy  \
# 0                                    Problem Solving  New York    Freshman
# 1  Leadership, Problem Solving, Public Speaking, ...    Boston    Graduate
# 2  Data Analysis, Leadership, Public Speaking, Ar...   Chicago      Junior
# 3    Public Speaking, Data Analysis, Problem Solving   Chicago    Graduate
# 4                                      Data Analysis   Chicago    Graduate
#
#               Major   GPA                                    Languages  \
# ...

# %%
df0.columns
# Out:
# Index(['StudentID', 'Name', 'AcademicInterest', 'ExtracurricularActivities',
#        'Skills', 'Location', 'YearOfStudy', 'Major', 'GPA', 'Languages',
#        'ClubMemberships', 'ResearchInterests'],
#       dtype='object')

# %%
df = df0.drop(columns=['StudentID', 'Name', 'AcademicInterest',
    'Skills', 'Location', 'YearOfStudy', 'Major', 'GPA', 'Languages',
    'ResearchInterests'])

# %%
df.head()
# Out:
#   ExtracurricularActivities                                    ClubMemberships
# 0               Debate Club  Music Club, Art Club, Sports Team, Debate Club...
# 1               Debate Club     Art Club, Music Club, Sports Team, Coding Club
# 2           Volunteer Group  Music Club, Art Club, Debate Club, Volunteer G...
# 3           Volunteer Group                       Sports Team, Volunteer Group
# 4               Sports Team           Sports Team, Volunteer Group, Music Club

# %%
df.columns
# Out:
# Index(['ExtracurricularActivities', 'ClubMemberships'], dtype='object')

# %%
df.to_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\Final Code\\Extra Curricular Activities Information\\Student Data Extended\\student_data_extended.csv")
