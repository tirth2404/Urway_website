# %%
import pandas as pd

# %%
# read the Dataset DATA (1).csv
df0 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\DATA (1).csv")

# %%
df0.head()
# Out:
#   STUDENT ID  1  2  3  4  5  6  7  8  9  ...  23  24  25  26  27  28  29  30  \
# 0   STUDENT1  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   1   2   1   1
# 1   STUDENT2  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   3   2   2   3
# 2   STUDENT3  2  2  2  3  2  2  2  2  4  ...   1   1   2   2   1   1   2   2
# 3   STUDENT4  1  1  1  3  1  2  1  2  1  ...   1   2   3   2   2   1   3   2
# 4   STUDENT5  2  2  1  3  2  2  1  3  1  ...   2   1   2   2   2   1   2   2
#
#    COURSE ID  GRADE
# 0          1      1
# 1          1      1
# 2          1      1
# 3          1      1
# 4          1      1
#
# [5 rows x 33 columns]

# %%
column_names = {
    1: "Student Age",
    2: "Sex",
    3: "Graduated High School Type",
    4: "Scholarship Type",
    5: "Additional Work",
    6: "Regular Artistic or Sports Activity",
    7: "Has Partner",
    8: "Total Salary",
    9: "Transportation to University",
    10: "Accommodation Type",
    11: "Mother Education",
    12: "Father Education",
    13: "Number of Siblings",
    14: "Parental Status",
    15: "Mother Occupation",
    16: "Father Occupation",
    17: "Weekly Study Hours",
    18: "Reading Frequency (Non-Scientific)",
    19: "Reading Frequency (Scientific)",
    20: "Seminars / Conferences Attendance",
    21: "Impact of Projects on Success",
    22: "Class Attendance",
    23: "Midterm Preparation (With Whom)",
    24: "Midterm Preparation (When)",
    25: "Taking Notes in Class",
    26: "Listening in Class",
    27: "Discussion Improves Success",
    28: "Flip Classroom Usefulness",
    29: "Last Semester CGPA",
    30: "Expected Graduation CGPA"
}

# %%
# Rename using column positions
df0.columns = [
    column_names.get(i + 1, col)   # keep original name if not mapped
    for i, col in enumerate(df0.columns)
]

# %%
# Save result
df0.to_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\Data_renamed.csv", index=False)
