# %%
import pandas as pd

# %%
# read the Dataset career_recommender.csv
df0 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\career_recommender.csv")

# %%
df0.head()
# Out:
#   What is your name? What is your gender? What was your course in UG?  \
# 0        A.Uha Priya               Female                        B.Sc
# 1              Aadil                 Male                         B.E
# 2            Aakriti               Female                          BA
# 3     Aanchal sharma               Female                         MBA
# 4   Aangkeeta Sarkar               Female                      B.Tech
#
#   What is your UG specialization? Major Subject (Eg; Mathematics)  \
# 0                              Computer Applications
# 1                       Computer Science Engineering
# 2                                         Psychology
# 3                                           Commerce
# 4                        Instrumentation Engineering
#
#                             What are your interests?  \
# 0                                    Cloud computing
# 1                                         Technology
# ...

# %%
df0.columns
# Out:
# Index(['What is your name?', 'What is your gender?',
#        'What was your course in UG?',
#        'What is your UG specialization? Major Subject (Eg; Mathematics)',
#        'What are your interests?',
#        'What are your skills ? (Select multiple if necessary)',
#        'What was the average CGPA or Percentage obtained in under graduation?',
#        'Did you do any certification courses additionally?',
#        'If yes, please specify your certificate course title.',
#        'Are you working?',
#        'If yes, then what is/was your first Job title in your current field of work? If not applicable, write NA.               ',
#        'Have you done masters after undergraduation? If yes, mention your field of masters.(Eg; Masters in Mathematics)'],
#       dtype='object')

# %%
df = df0.drop(columns=['What is your name?', 'What is your gender?','Did you do any certification courses additionally?', 'If yes, please specify your certificate course title.', 'Are you working?', 'If yes, then what is/was your first Job title in your current field of work? If not applicable, write NA.               ', 'Have you done masters after undergraduation? If yes, mention your field of masters.(Eg; Masters in Mathematics)'])

# %%
df.head()
# Out:
#   What was your course in UG?  \
# 0                        B.Sc
# 1                         B.E
# 2                          BA
# 3                         MBA
# 4                      B.Tech
#
#   What is your UG specialization? Major Subject (Eg; Mathematics)  \
# 0                              Computer Applications
# 1                       Computer Science Engineering
# 2                                         Psychology
# 3                                           Commerce
# 4                        Instrumentation Engineering
#
#                             What are your interests?  \
# 0                                    Cloud computing
# 1                                         Technology
# 2                         Understand human behaviour
# 3  Sales/Marketing;Trading;Understand human behav...
# 4                                         Technology
#
#   What are your skills ? (Select multiple if necessary)  \
# 0                                    Python;SQL;Java
# ...

# %%
df.columns
# Out:
# Index(['What was your course in UG?',
#        'What is your UG specialization? Major Subject (Eg; Mathematics)',
#        'What are your interests?',
#        'What are your skills ? (Select multiple if necessary)',
#        'What was the average CGPA or Percentage obtained in under graduation?'],
#       dtype='object')

# %%
df.to_csv(df.to_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\Final Code\\Education Information\\Carrier recommender\\career_recommender.csv"))
# Out:
# ',What was your course in UG?,What is your UG specialization? Major Subject (Eg; Mathematics),What are your interests?,What are your skills ? (Select multiple if necessary),What was the average CGPA or Percentage obtained in under graduation?\r\n0,B.Sc,Computer Applications,Cloud computing,Python;SQL;Java,85\r\n1,B.E,Computer Science Engineering,Technology,"Critical Thinking, Analytic Thinking, SQL, Programming, Work under Pressure, Logical Skills, Problem Solving skills",66.5\r\n2,BA,Psychology,Understand human behaviour,People management;Communication skills,64.6\r\n3,MBA,Commerce,Sales/Marketing;Trading;Understand human behaviour;Home interior design,Accounting Skills;Critical Thinking,75.525\r\n4,B.Tech,Instrumentation Engineering,Technology,"\nPLC Allen Bradley;PLC Ladder Logic;LabVIEW;Business Analysis;End-to-End ProjectManagement;Crossfunctional Team Leadership;Requirements Gathering;Lean Six Sigma;Lean six sigma blackbelt;Productivity Improvement",70.68\r\n5,B.Tech,Computer S
# ...
