# %%
import pandas as pd

# Read the Dataset Data_renamed.csv (FIXED PATH — file is present in repo)
df0 = pd.read_csv("../DataSet/Data_renamed.csv")

# %%
df0.head()
# Out:
#   Student Age  Sex  Graduated High School Type  Scholarship Type  \
# 0    STUDENT1    2                           2                 3
# 1    STUDENT2    2                           2                 3
# 2    STUDENT3    2                           2                 2
# 3    STUDENT4    1                           1                 1
# 4    STUDENT5    2                           2                 1
#
#    Additional Work  Regular Artistic or Sports Activity  Has Partner  \
# 0                3                                    1            2
# 1                3                                    1            2
# 2                3                                    2            2
# 3                3                                    1            2
# 4                3                                    2            2
#
#    Total Salary  Transportation to University  Accommodation Type  ...  \
# 0             2                             1                   1  ...
# ...

# %%
df0.columns
# Out:
# Index(['Student Age', 'Sex', 'Graduated High School Type', 'Scholarship Type',
#        'Additional Work', 'Regular Artistic or Sports Activity', 'Has Partner',
#        'Total Salary', 'Transportation to University', 'Accommodation Type',
#        'Mother Education', 'Father Education', 'Number of Siblings',
#        'Parental Status', 'Mother Occupation', 'Father Occupation',
#        'Weekly Study Hours', 'Reading Frequency (Non-Scientific)',
#        'Reading Frequency (Scientific)', 'Seminars / Conferences Attendance',
#        'Impact of Projects on Success', 'Class Attendance',
#        'Midterm Preparation (With Whom)', 'Midterm Preparation (When)',
#        'Taking Notes in Class', 'Listening in Class',
#        'Discussion Improves Success', 'Flip Classroom Usefulness',
#        'Last Semester CGPA', 'Expected Graduation CGPA', '30', 'COURSE ID',
#        'GRADE'],
#       dtype='object')

# %%
df = df0.drop(columns=[
    'Student Age', 'Sex', 'Graduated High School Type',
    'Additional Work', 'Regular Artistic or Sports Activity', 'Has Partner',
    'Total Salary', 'Transportation to University', 'Accommodation Type',
    'Mother Education', 'Father Education', 'Number of Siblings',
    'Parental Status', 'Mother Occupation', 'Father Occupation',
    'Reading Frequency (Non-Scientific)', 'Reading Frequency (Scientific)',
    'Seminars / Conferences Attendance', 'Impact of Projects on Success',
    'Class Attendance', 'Midterm Preparation (With Whom)',
    'Taking Notes in Class', 'Listening in Class',
    'Discussion Improves Success', 'Flip Classroom Usefulness',
    'Last Semester CGPA', 'Expected Graduation CGPA', '30', 'COURSE ID', 'GRADE'
])

df.head()
# Out:
#    Scholarship Type  Weekly Study Hours  Midterm Preparation (When)
# 0                 3                   5                           1
# 1                 3                   1                           1
# 2                 2                   1                           1
# 3                 1                   1                           1
# 4                 1                   4                           2

# %%
df.columns
# Out:
# Index(['Scholarship Type', 'Weekly Study Hours', 'Midterm Preparation (When)'], dtype='object')

# %%
import os

# FIXED: was a hardcoded absolute Windows path
# Output goes to Education Information folder
out_dir = "../Education Information/Higher_Edu_Std_Perf_Eval"
os.makedirs(out_dir, exist_ok=True)

out_path = os.path.join(out_dir, "higher_edu_std_perf_eval.csv")
df.to_csv(out_path, index=False)
print(f"Saved to {out_path}")
# Out:
# Saved to ../Education Information/Higher_Edu_Std_Perf_Eval\higher_edu_std_perf_eval.csv
