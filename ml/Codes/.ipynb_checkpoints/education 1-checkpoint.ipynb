# %%
import pandas as pd

# %%
# read the Dataset career_path_in_all_field.csv
df0 = pd.read_csv("..\DataSet\career_path_in_all_field.csv")

# %%
df0.head()
# Out:
#          Field                   Career       GPA  Extracurricular_Activities  \
# 0  Engineering            Urban Planner  3.530439                           5
# 1    Chemistry             Art Director  4.018247                           1
# 2  Engineering                  Chemist  4.636733                           1
# 3      Physics                  Manager  4.052693                           3
# 4          Law  Education Administrator  4.834850                           0
#
#    Internships  Projects  Leadership_Positions  Field_Specific_Courses  \
# 0            0         2                     0                       3
# 1            2         0                     0                       8
# 2            0         0                     0                       5
# 3            1         3                     0                       1
# 4            2         4                     0                       0
#
#    Research_Experience  Coding_Skills  Communication_Skills  \
# ...

# %%
df0.columns
# Out:
# Index(['Field', 'Career', 'GPA', 'Extracurricular_Activities', 'Internships',
#        'Projects', 'Leadership_Positions', 'Field_Specific_Courses',
#        'Research_Experience', 'Coding_Skills', 'Communication_Skills',
#        'Problem_Solving_Skills', 'Teamwork_Skills', 'Analytical_Skills',
#        'Presentation_Skills', 'Networking_Skills', 'Industry_Certifications'],
#       dtype='object')

# %%
df = df0.drop(columns=['Field', 'Career', 'GPA', 'Extracurricular_Activities', 'Field_Specific_Courses','Research_Experience', 'Coding_Skills', 'Industry_Certifications'])

# %%
df.columns
# Out:
# Index(['Internships', 'Projects', 'Leadership_Positions',
#        'Communication_Skills', 'Problem_Solving_Skills', 'Teamwork_Skills',
#        'Analytical_Skills', 'Presentation_Skills', 'Networking_Skills'],
#       dtype='object')

# %%
df.to_csv("../Presonal Information/Carrier Path/career_path.csv")
