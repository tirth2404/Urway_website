# %%
import pandas as pd

# %%
# read the student-mat.csv
df01 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\student-mat.csv", sep=';')
# read the student-por.csv
df02 = pd.read_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\DataSet\\student-por.csv", sep=';')

# %%
df01.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df02.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
print(df01.shape)
print(df02.shape)
# Out:
# (395, 33)
# (649, 33)

# %%
df0 = pd.concat([df01, df02],axis=0)

# %%
df0 = df0.drop_duplicates()
print(df0.shape)
# Out:
# (1044, 33)

# %%
df0.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df = df0.drop(columns=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
    'Mjob', 'Fjob', 'reason', 'guardian','nursery', 'higher', 'romantic', 'famrel', 'Dalc',
    'Walc', 'health', 'absences', 'G1', 'G2', 'G3'])

# %%
df.head()
# Out:
#    traveltime  studytime  failures schoolsup famsup paid activities internet  \
# 0           2          2         0       yes     no   no         no       no
# 1           1          2         0        no    yes   no         no      yes
# 2           1          2         3       yes     no  yes         no      yes
# 3           1          3         0        no    yes  yes        yes      yes
# 4           1          2         0        no    yes  yes         no       no
#
#    freetime  goout
# 0         3      4
# 1         3      3
# 2         3      2
# 3         2      2
# 4         3      2

# %%
df.columns
# Out:
# Index(['traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'internet', 'freetime', 'goout'],
#       dtype='object')

# %%
df.to_csv("C:\\Users\\HIMPADMA\\OneDrive\\Desktop\\Dokumen\\University Work\\U'rWay\\U'rWay Personality Classification\\Final Code\\Presonal Information\\Student Performance\\stu_perf.csv")
